# %% [markdown]
# # EVALUANDO ERRORES EN MODELOS DE CLASIFICACION

# %% [markdown]
# # 1. Exactitud
# ### Numero de predicciones correctas (Tanto NEGATIVAS como POSITIVAS) respecto a todo el conjunto de datos.

# %% [markdown]
# # 2. Precisión
# #### Evalua los positivos correctos respecto a los positivos correctos como a los falsos positivos
# EVALUA LOS CASOS CORRECTOS RESPECTO A TODOS LOS CASOS PREDICHOS POR LA MAQUINA COMO CORRECTOS
# ![Precision.JPG](attachment:Precision.JPG)

# %% [markdown]
# # 3. Sensibilidad
# ### Numero de casos positivos diagnosticados correctamente sobre el total de casos que eran positivos realmente junto con los que se diagnosticaron mal
# LOS NUMEROS DE CASOS POSITIVOS RESPECTO A TODOS LOS POSITIVOS DE LA VIDA REAL
#
# ![Sensibilidad.JPG](attachment:Sensibilidad.JPG)

# %% [markdown]
# # 4. Especificidad
# ### Verdaderos negativos predichos respecto a todos los negativos reales
# ![Especificidad.JPG](attachment:Especificidad.JPG)

# %% [markdown]
# # PUNTAJDE DE F1
